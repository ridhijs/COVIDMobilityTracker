# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
import googlemaps

# %%
df = pd.read_csv("https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv?cachebust=6d352e35dcffafce")
df = df.fillna(method='ffill')
df = df.replace(np.nan, '', regex=True)
df
# Out:
# C:\Users\yugmi\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        country_region_code        country_region       sub_region_1  \
# 0                       AE  United Arab Emirates
# 1                       AE  United Arab Emirates
# 2                       AE  United Arab Emirates
# 3                       AE  United Arab Emirates
# 4                       AE  United Arab Emirates
# ...                    ...                   ...                ...
# 458560                  ZW              Zimbabwe  Midlands Province
# 458561                  ZW              Zimbabwe  Midlands Province
# 458562                  ZW              Zimbabwe  Midlands Province
# 458563                  ZW              Zimbabwe  Midlands Province
# 458564                  ZW              Zimbabwe  Midlands Province
#
#          sub_region_2        date  \
# 0                      2020-02-15
# 1                      2020-02-16
# 2                      2020-02-17
# 3                      2020-02-18
# 4                      2020-02-19
# ...               ...         ...
# 458560  Weston County  2020-05-21
# 458561  Weston County  2020-05-22
# 458562  Weston County  2020-05-23
# 458563  Weston County  2020-05-24
# 458564  Weston County  2020-05-25
#
#         retail_and_recreation_percent_change_from_baseline  \
# 0                                                     0.0
# 1                                                     1.0
# 2                                                    -1.0
# 3                                                    -2.0
# 4                                                    -2.0
# ...                                                   ...
# 458560                                              -49.0
# 458561                                              -49.0
# 458562                                              -49.0
# 458563                                              -49.0
# 458564                                              -49.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                     4.0
# 1                                                     4.0
# 2                                                     1.0
# 3                                                     1.0
# 4                                                     0.0
# ...                                                   ...
# 458560                                              -35.0
# 458561                                              -35.0
# 458562                                              -35.0
# 458563                                              -35.0
# 458564                                              -35.0
#
#         parks_percent_change_from_baseline  \
# 0                                      5.0
# 1                                      4.0
# 2                                      5.0
# 3                                      5.0
# 4                                      4.0
# ...                                    ...
# 458560                               -54.0
# 458561                               -54.0
# 458562                               -54.0
# 458563                               -54.0
# 458564                               -54.0
#
#         transit_stations_percent_change_from_baseline  \
# 0                                                 0.0
# 1                                                 1.0
# 2                                                 1.0
# 3                                                 0.0
# 4                                                -1.0
# ...                                               ...
# 458560                                          -72.0
# 458561                                          -72.0
# 458562                                          -72.0
# 458563                                          -72.0
# 458564                                          -72.0
#
#         workplaces_percent_change_from_baseline  \
# 0                                           2.0
# 1                                           2.0
# 2                                           2.0
# 3                                           2.0
# 4                                           2.0
# ...                                         ...
# 458560                                    -18.0
# 458561                                    -12.0
# 458562                                     12.0
# 458563                                     16.0
# 458564                                    -52.0
#
#         residential_percent_change_from_baseline
# 0                                            1.0
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0
# ...                                          ...
# 458560                                      38.0
# 458561                                      38.0
# 458562                                      38.0
# 458563                                      38.0
# 458564                                      38.0
#
# [458565 rows x 11 columns]

# %%
def get_geo_coordinates(address):
    """
    param: address is the address of the location
    """
    gmaps = googlemaps.Client(key='AIzaSyAstu56DT6WjhZoqwSjV7FyT1e_r-PM9HI')
    geocode_result = gmaps.geocode(address)
    lat = geocode_result[0]["geometry"]["location"]['lat']
    lng = geocode_result[0]["geometry"]["location"]['lng']
    return (lat, lng)

# %%
get_geo_coordinates("United States")
# Out:
# (37.09024, -95.712891)

# %%
#Get all data
df = pd.read_csv("https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv?cachebust=6d352e35dcffafce")
df = df.fillna(method='ffill')
df = df.replace(np.nan, '', regex=True)
place_data = {}
coordinates_data = {}
print((dt.strptime(df.iloc[2]["date"],'%Y-%m-%d')-dt.strptime(df.iloc[0]["date"],'%Y-%m-%d')).total_seconds())
for i in range(len(df)-1):
    row_one = df.iloc[i]
    date_one = dt.strptime(df.iloc[i]["date"], '%Y-%m-%d')
    date_two = dt.strptime(df.iloc[i+1]["date"], '%Y-%m-%d')
    seconds_difference = (date_two - date_one).total_seconds()
    if seconds_difference < 0:
        address = df.iloc[i]["country_region"] + " "
        address += df.iloc[i]["sub_region_1"] + " "
        address += df.iloc[i]["sub_region_2"] + " "
        print(address)
        place_data[address] = row_one["retail_and_recreation_percent_change_from_baseline"] + row_one["grocery_and_pharmacy_percent_change_from_baseline"] + row_one["parks_percent_change_from_baseline"] + row_one["transit_stations_percent_change_from_baseline"] + row_one["workplaces_percent_change_from_baseline"] + row_one["residential_percent_change_from_baseline"]
        coordinates = get_geo_coordinates(address)
        print(coordinates)
        coordinates_data[coordinates] = row_one["retail_and_recreation_percent_change_from_baseline"] + row_one["grocery_and_pharmacy_percent_change_from_baseline"] + row_one["parks_percent_change_from_baseline"] + row_one["transit_stations_percent_change_from_baseline"] + row_one["workplaces_percent_change_from_baseline"] + row_one["residential_percent_change_from_baseline"]
print(coordinates_data)
# Out:
# 172800.0
# United Arab Emirates
# (23.424076, 53.847818)
# United Arab Emirates Abu Dhabi
# (24.453884, 54.3773438)
# United Arab Emirates Ajman
# (25.4052165, 55.5136433)
# United Arab Emirates Dubai
# (25.2048493, 55.2707828)
# United Arab Emirates Fujairah
# (25.1288099, 56.3264849)
# United Arab Emirates Ras al Khaimah
# (25.6741343, 55.9804173)
# United Arab Emirates Sharjah
# (25.3462553, 55.4209317)
# United Arab Emirates Umm Al Quawain
# (25.5204824, 55.7133909)
# Afghanistan Umm Al Quawain
# (25.5059782, 55.5917085)
# Antigua and Barbuda Umm Al Quawain
# (25.5204824, 55.7133909)
# Antigua and Barbuda Saint George
# (17.1078489, -61.7882743)
# Antigua and Barbuda Saint John
# (17.1274104, -61.84677199999999)
# Antigua and Barbuda Saint Mary
# (17.0512064, -61.87602829999999)
# Antigua and Barbuda Saint Paul
# (17.0371588, -61.7824256)
# Angola Saint Paul
# (42.6392736, -79.0408594)
# Angola Benguela Province
# (-12.8003744, 13.914399)
# Angola Cabinda Province
# (-5.024874899999999, 12.3463875)
# Angola Huambo Province
# (-12.5268221, 15.5943388)
# Angola Huila Province
# (-14.9280553, 14.6587821)
# Angola Luanda Province
# (-9.035088, 13.2663479)
# Argentina Luanda Province
# (-9.035088, 13.2663479)
# Argentina Buenos Aires
# (-34.6036844, -58.3815591)
# Argentina Buenos Aires Province
# (-37.2017285, -59.84106969999999)
# Argentina Catamarca Province
# (-28.4715877, -65.7877209)
# Argentina Chaco Province
# (-27.4257175, -59.02437839999999)
# Argentina Chubut Province
# (-43.2934246, -65.11148179999999)
# Argentina Cordoba
# (-31.42008329999999, -64.1887761)
# Argentina Corrientes
# (-27.4692131, -58.8306349)
# Argentina Entre Rios
# (-31.7746654, -60.49564609999999)
# Argentina Formosa Province
# (-26.1894804, -58.22428060000001)
# Argentina Jujuy
# (-24.1857864, -65.2994767)
# Argentina La Pampa
# (-36.6147573, -64.2839209)
# Argentina La Rioja Province
# (-29.4193793, -66.8559932)
# Argentina Mendoza Province
# (-32.8896247, -68.8526867)
# Argentina Misiones Province
# (-27.4269255, -55.9467076)
# Argentina Neuquen
# (-38.9516784, -68.0591888)
# Argentina Río Negro
# (-40.8261434, -63.0266339)
# Argentina Salta Province
# (-24.7997688, -65.4150367)
# Argentina San Juan Province
# (-31.5287127, -68.5360403)
# Argentina San Luis Province
# (-33.2962042, -66.32949479999999)
# Argentina Santa Cruz Province
# (-51.6352821, -69.24743529999999)
# Argentina Santa Fe Province
# (-31.5855109, -60.72380159999999)
# Argentina Santiago del Estero Province
# (-27.7833574, -64.264167)
# Argentina Tierra del Fuego Province
# (-54.8053998, -68.3242061)
# Argentina Tucumán
# (-26.8082848, -65.2175903)
# Austria Tucumán
# (-26.8082848, -65.2175903)
# Austria Burgenland
# (47.15371649999999, 16.2688797)
# Austria Carinthia
# (46.722203, 14.1805882)
# Austria Lower Austria
# (48.10807699999999, 15.8049558)
# Austria Salzburg
# (47.80949, 13.05501)
# Austria Styria
# (47.3593442, 14.4699827)
# Austria Tyrol
# (47.2537414, 11.601487)
# Austria Upper Austria
# (48.025854, 13.9723665)
# Austria Vienna
# (48.2081743, 16.3738189)
# Austria Vorarlberg
# (47.2497427, 9.9797373)
# Australia Vorarlberg
# (47.2497427, 9.9797373)
# Australia Australian Capital Territory
# (-35.4734679, 149.0123679)
# Australia New South Wales
# (-31.2532183, 146.921099)
# Australia Northern Territory
# (-19.4914108, 132.5509603)
# Australia Queensland
# (-20.9175738, 142.7027956)
# Australia South Australia
# (-30.0002315, 136.2091547)
# Australia Tasmania
# (-41.4545196, 145.9706647)
# Australia Victoria
# (-37.4713077, 144.7851531)
# Australia Western Australia
# (-27.6728168, 121.6283098)
# Aruba Western Australia
# (-32.0860564, 115.9497547)
# Bosnia and Herzegovina Western Australia
# (43.915886, 17.679076)
# Barbados Western Australia
# (-31.8183453, 115.7417375)
# Barbados Christ Church
# (13.0728209, -59.5261392)
# Barbados Saint George
# (13.1401378, -59.54611249999999)
# Barbados Saint James
# (13.1842181, -59.6304714)
# Barbados Saint John
# (13.1824334, -59.5033496)
# Barbados Saint Lucy
# (13.3041806, -59.6052862)
# Barbados Saint Michael
# (13.1132219, -59.59880889999999)
# Barbados Saint Peter
# (13.2600459, -59.621862)
# Barbados Saint Philip
# (13.1256336, -59.456055)
# Barbados Saint Thomas
# (13.1740547, -59.5827556)
# Bangladesh Saint Thomas
# (23.7102077, 90.4121036)
# Belgium Saint Thomas
# (18.3380965, -64.8940946)
# Belgium Brussels
# (50.8503463, 4.3517211)
# Belgium Flanders
# (51.0108706, 3.7264613)
# Belgium Wallonia
# (50.4175637, 4.451006599999999)
# Burkina Faso Wallonia
# (50.4175637, 4.451006599999999)
# Burkina Faso Centre Region
# (12.3425897, -1.443469)
# Burkina Faso Centre-Est Region
# (11.5247674, -0.1494988)
# Burkina Faso Centre-Ouest Region
# (11.8798466, -2.302446)
# Burkina Faso Hauts-Bassins Region
# (11.4942003, -4.2333355)
# Bulgaria Hauts-Bassins Region
# (11.4942003, -4.2333355)
# Bulgaria Blagoevgrad Province
# (42.0208614, 23.0943356)
# Bulgaria Burgas
# (42.50479259999999, 27.4626361)
# Bulgaria Dobrich Province
# (43.57278600000001, 27.8272802)
# Bulgaria Gabrovo
# (42.8742212, 25.3186837)
# Bulgaria Haskovo Province
# (41.9344178, 25.5554672)
# Bulgaria Jambol
# (42.48419990000001, 26.5035023)
# Bulgaria Kardzhali Province
# (41.6338416, 25.3776687)
# Bulgaria Kyustendil Province
# (42.2868799, 22.6939635)
# Bulgaria Lovec
# (43.1369534, 24.7141906)
# Bulgaria Montana Province
# (43.4085148, 23.2257589)
# Bulgaria Pazardzhik
# (42.1927654, 24.3335662)
# Bulgaria Pernik
# (42.6051862, 23.0378368)
# Bulgaria Pleven Province
# (43.4170169, 24.6066708)
# Bulgaria Plovdiv Province
# (42.135281, 24.7454204)
# Bulgaria Razgrad
# (43.53367189999999, 26.5411165)
# Bulgaria Ruse
# (43.83557130000001, 25.9656554)
# Bulgaria Shumen Province
# (43.271252, 26.9360985)
# Bulgaria Silistra
# (44.1147271, 27.2671901)
# Bulgaria Sliven Province
# (42.6816702, 26.3228569)
# Bulgaria Smoljan
# (41.5774233, 24.7011138)
# Bulgaria Sofia City Province
# (42.7570109, 23.4504683)
# Bulgaria Sofia Province
# (42.67344, 23.8334937)
# Bulgaria Stara Zagora
# (42.4257769, 25.6344644)
# Bulgaria Targovishte Province
# (43.2462349, 26.5691251)
# Bulgaria Varna
# (43.2140504, 27.9147333)
# Bulgaria Veliko Tarnovo Province
# (43.0756539, 25.61715)
# Bulgaria Vidin
# (43.996159, 22.8679302)
# Bulgaria Vraca
# (43.2102375, 23.5528803)
# Bahrain Vraca
# (43.2102375, 23.5528803)
# Benin Vraca
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-9c1eb5902040> in <module>
#      17         print(address)
#      18         place_data[address] = row_one["retail_and_recreation_percent_change_from_baseline"] + row_one["grocery_and_pharmacy_percent_change_from_baseline"] + row_one["parks_percent_change_from_baseline"] + row_one["transit_stations_percent_change_from_baseline"] + row_one["workplaces_percent_change_from_baseline"] + row_one["residential_percent_change_from_baseline"]
# ---> 19         coordinates = get_geo_coordinates(address)
#      20         print(coordinates)
#      21         coordinates_data[coordinates] = row_one["retail_and_recreation_percent_change_from_baseline"] + row_one["grocery_and_pharmacy_percent_change_from_baseline"] + row_one["parks_percent_change_from_baseline"] + row_one["transit_stations_percent_change_from_baseline"] + row_one["workplaces_percent_change_from_baseline"] + row_one["residential_percent_change_from_baseline"]
#
# <ipython-input-20-2ef59d97b79b> in get_geo_coordinates(address)
#       5     gmaps = googlemaps.Client(key='AIzaSyAstu56DT6WjhZoqwSjV7FyT1e_r-PM9HI')
#       6     geocode_result = gmaps.geocode(address)
# ----> 7     lat = geocode_result[0]["geometry"]["location"]['lat']
#       8     lng = geocode_result[0]["geometry"]["location"]['lng']
#       9     return (lat, lng)
#
# IndexError: list index out of range

# %%
#Get New York data
df = pd.read_csv("https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv?cachebust=6d352e35dcffafce")
df = df.fillna(method='ffill')
df = df.replace(np.nan, '', regex=True)
place_data = {}
coordinates_data = {}
places = []
coordinate_points = []
mobility = []
print((dt.strptime(df.iloc[2]["date"],'%Y-%m-%d')-dt.strptime(df.iloc[0]["date"],'%Y-%m-%d')).total_seconds())
for i in range(len(df)-1):
    row_one = df.iloc[i]
    if (df.iloc[i]["sub_region_1"] == "New York"):
        date_one = dt.strptime(df.iloc[i]["date"], '%Y-%m-%d')
        date_two = dt.strptime(df.iloc[i+1]["date"], '%Y-%m-%d')
        seconds_difference = (date_two - date_one).total_seconds()
        if seconds_difference < 0:
            address = df.iloc[i]["country_region"] + " "
            address += df.iloc[i]["sub_region_1"] + " "
            address += df.iloc[i]["sub_region_2"] + " "
            place_data[address] = row_one["retail_and_recreation_percent_change_from_baseline"] + row_one["grocery_and_pharmacy_percent_change_from_baseline"] + row_one["parks_percent_change_from_baseline"] + row_one["transit_stations_percent_change_from_baseline"] + row_one["workplaces_percent_change_from_baseline"] + row_one["residential_percent_change_from_baseline"]
            places.append(address)
            mobility.append(place_data[address])
            coordinates = get_geo_coordinates(address)
            coordinate_points.append(coordinates)
            coordinates_data[coordinates] = row_one["retail_and_recreation_percent_change_from_baseline"] + row_one["grocery_and_pharmacy_percent_change_from_baseline"] + row_one["parks_percent_change_from_baseline"] + row_one["transit_stations_percent_change_from_baseline"] + row_one["workplaces_percent_change_from_baseline"] + row_one["residential_percent_change_from_baseline"]
df2 = pd.DataFrame({"Places": places, "Coordinates": coordinate_points, "Mobility": mobility}, columns=["Places", "Coordinates", "Mobility"])
df2.to_csv("Mobility_ny.csv")
print(coordinates_data)
# Out:
# 172800.0
